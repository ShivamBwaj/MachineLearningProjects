# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# !wget https://www.kaggle.com/datasets/rsadiq/salary/download/djJuFrSnYRHztGPbp7XK%2Fversions%2FyHS3J1sLOzSXJj9dkJmV%2Ffiles%2FSalary.csv?datasetVersionNumber=1
# Out:
# --2025-10-27 11:24:27--  https://www.kaggle.com/datasets/rsadiq/salary/download/djJuFrSnYRHztGPbp7XK%2Fversions%2FyHS3J1sLOzSXJj9dkJmV%2Ffiles%2FSalary.csv?datasetVersionNumber=1
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Frsadiq%2Fsalary%2Fversions%2F1%3Fresource%3Ddownload [following]
# --2025-10-27 11:24:28--  https://www.kaggle.com/account/login?titleType=dataset-downloads&showDatasetDownloadSkip=False&messageId=datasetsWelcome&returnUrl=%2Fdatasets%2Frsadiq%2Fsalary%2Fversions%2F1%3Fresource%3Ddownload
# Reusing existing connection to www.kaggle.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘djJuFrSnYRHztGPbp7XK%2Fversions%2FyHS3J1sLOzSXJj9dkJmV%2Ffiles%2FSalary.csv?datasetVersionNumber=1’
#
# djJuFrSnYRHztGPbp7X     [ <=>                ]   5.07K  --.-KB/s    in 0s
#
# 2025-10-27 11:24:28 (50.8 MB/s) - ‘djJuFrSnYRHztGPbp7XK%2Fversions%2FyHS3J1sLOzSXJj9dkJmV%2Ffiles%2FSalary.csv?datasetVersionNumber=1’ saved [5195]

# %%
df=pd.read_csv("Salary.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df.loc[:, ['YearsExperience']].values
y = df.loc[:, 'Salary'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

model=LinearRegression()
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([110877.79583392,  64678.96421127, 104033.52448241,  90344.98177941,
#         71523.23556278, 119433.1350233 ,  80934.10867109,  63823.43029234,
#         56979.15894083,  73234.30340065,  61256.82853552])

# %%
y_test
# Out:
# array([116969,  57081, 109431,  98273,  67938, 121872,  93940,  56957,
#         64445,  66029,  57189])

# %%
plt.scatter(X_train , y_train, color='red')
plt.plot(X_train,model.predict(X_train))
